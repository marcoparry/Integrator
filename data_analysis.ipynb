# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
path_fig = "/Users/marcoparrinello/Desktop/Tesi/tesi/figures"

i = np.random.randint(0, 38)

# data = np.genfromtxt(f"data/cancer_{i}.dat")

df = pd.read_csv(f"data/cancer_{i}.dat", sep="\t")

# interesting_data: 353, 187

# %%
df = pd.read_csv(f"data/cancer_initial_condition_0.dat", sep="\t")
fig, ax = plt.subplots()
df[df["t"]<100].plot("t", ["x1", "x2", "x3", "x4", "x5"], ax=ax)
# fig.savefig(f"{path_fig}/time_evolution_example.png")
# Out:
# <Axes: xlabel='t'>

# %%
df = pd.read_csv(f"data/custom_cancer_1.dat", sep="\t")
fig, ax = plt.subplots(2, 1)
df[df["t"]<200].plot("t", ["x4", "x5"], subplots=True, ax=ax)
# fig.savefig(f"{path_fig}/time_evolution_example_oscillation_transient.png")
# Out:
# array([<Axes: xlabel='t'>, <Axes: xlabel='t'>], dtype=object)

# %%
df = pd.read_csv(f"data/custom_cancer_6.dat", sep="\t")
fig, ax = plt.subplots(2, 1)
df[df["t"]<500].plot("t", ["x4", "x5"], subplots=True, ax=ax)
# fig.savefig(f"{path_fig}/time_evolution_example_oscillation_transient.png")
# Out:
# array([<Axes: xlabel='t'>, <Axes: xlabel='t'>], dtype=object)

# %%
i = 27
# i = np.random.randint(0, 38)
print(i)

df = pd.read_csv(f"data/cancer_{i}.dat", sep="\t")
#df[["x1", "x2", "x3", "x4", "x5"]] = MinMaxScaler().fit_transform(df[["x1", "x2", "x3", "x4", "x5"]])
fig, ax = plt.subplots(5, 1, sharex=True, figsize=(10, 10))
# fig, ax = plt.subplots()
df[df["t"]<1000].plot("t", ["x1", "x2", "x3", "x4", "x5"], ax=ax, subplots=True)
# df[df["t"]<300].plot("t", ["x4", "x5"], ax=ax, subplots=True)
# fig.savefig(f"{path_fig}/oscillations_complete_asymptotic.png")
# Out:
# 27
# array([<Axes: xlabel='t'>, <Axes: xlabel='t'>, <Axes: xlabel='t'>,
#        <Axes: xlabel='t'>, <Axes: xlabel='t'>], dtype=object)

# %%
i = 7
# i = np.random.randint(0, 38)
print(i)

df = pd.read_csv(f"data/cancer_{i}.dat", sep="\t")
#df[["x1", "x2", "x3", "x4", "x5"]] = MinMaxScaler().fit_transform(df[["x1", "x2", "x3", "x4", "x5"]])
fig, ax = plt.subplots(5, 1, figsize=(10, 15))
df[df["t"]<100].plot("t", ["x1", "x2", "x3", "x4", "x5"], ax=ax, subplots=True)
# df[df["t"]<50].plot("t", ["x4", "x5"], ax=ax, subplots=True)
# fig.savefig(f"{path_fig}/immune_win_complete.png")
# Out:
# 7

# %%
i = 35
#i = np.random.randint(0, 38)
print(i)

df = pd.read_csv(f"data/cancer_{i}.dat", sep="\t")
#df[["x1", "x2", "x3", "x4", "x5"]] = MinMaxScaler().fit_transform(df[["x1", "x2", "x3", "x4", "x5"]])
fig, ax = plt.subplots(2, 1)
# df[df["t"]<100].plot("t", ["x1", "x2", "x3", "x4", "x5"], ax=ax, subplots=True)
df[df["t"]<100].plot("t", ["x4", "x5"], ax=ax, subplots=True)
# fig.savefig(f"{path_fig}/cancer_win_x4x5_subplots.png")
# Out:
# 35

# %%
filename = "cancer_different_m1"
i = np.random.randint(0, 202)

i = 60
i_list = [32, 36, 38, 39, 41, 50, 60, 61]
for i in i_list:
    df = pd.read_csv(f"data/{filename}_{i}.dat", sep="\t")
    #df[["x1", "x2", "x3", "x4", "x5"]] = MinMaxScaler().fit_transform(df[["x1", "x2", "x3", "x4", "x5"]])
    fig, ax = plt.subplots(2, 1, figsize=(8, 6))
    # df[df["t"]<100].plot("t", ["x1", "x2", "x3", "x4", "x5"], ax=ax, subplots=True)
    df[df["t"]<400].plot("t", ["x4", "x5"], ax=ax, subplots=True)
    # fig.savefig(f"{path_fig}/different_m1_{i}.png")
