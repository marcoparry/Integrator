# %%
import numpy as np
import matplotlib.pyplot as plt

data = np.genfromtxt("data/cancer_2.dat")
print(len(data))
# Out:
# 81369

# %%
fig, ax = plt.subplots()
# ax.plot(data[:, 0], data[:, 1], label="x1")
# ax.plot(data[:, 0], data[:, 2], label="x2")
# ax.plot(data[:, 0], data[:, 3], label="x3")
ax.plot(data[:, 0], data[:, 4], label="x4")
ax.plot(data[:, 0], data[:, 5], label="x5")
fig.legend()

# %%
fig, axs = plt.subplots(3, 1, figsize=(10,15))
axs[0].plot(data[:, 0], data[:, 3])
axs[1].plot(data[:, 0], data[:, 4])
axs[2].plot(data[:, 0], data[:, 5])
